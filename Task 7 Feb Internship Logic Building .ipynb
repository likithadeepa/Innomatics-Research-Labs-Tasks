# %%
#Smart Light Controller
class smartlight:
    def __init__(self,light_name):
        self.light_name =light_name
        self.status="off"
    def turn_on(self):
        self.status="on"
    def turn_off(self):
        self.status= "off"
    def display_status(self):
        print(f"{self.light_name} is {self.status}")
light=smartlight("bedroomlight")
light.turn_on()
light.display_status()
# Out:
# bedroomlight is on

# %%
#Employee ID Card System
class employee:
    def __init__(self,name,emp_id,department):
        self.name=name
        self.emp_id=emp_id
        self.department=department
    def display_id_card(self):
        print("employee ID card")
        print(f"Name:{self.name}")
        print(f"ID:{self.emp_id}")
        print(f"Department:{self.department}")
emp=employee("rahul","emp102","IT")
emp.display_id_card()
# Out:
# employee ID card
# Name:rahul
# ID:emp102
# Department:IT

# %%
#Mobile Contact Record
class contacts:
    def __init__(self, name, phone):
        self.name=name
        self.phone=phone
    def save_contact(self):
        print("contact saved")
        print(f"name:{self.name}")
        print(f"phone:{self.phone}")
contact=contacts("anita","327342121")
contact.save_contact()
# Out:
# contact saved
# name:anita
# phone:327342121

# %%
#Product Price Tag Generator
class products:
    def __init__(self,product_name,price):
        self.product_name=product_name
        self.price=price
    def display_price_tag(self):
        print(f"product:{self.product_name}")
        print(f"price:₹{self.price}")
product=products("head phones",3499)
product.display_price_tag()
# Out:
# product:head phones
# price:₹3499

# %%
#Movie Rating Display System
class movie:
    def __init__(self,moviename,rating):
        self.moviename=moviename
        self.rating=rating
    def display_movie_details(self):
        print(f"movie:{self.moviename}")
        print(f"rating:{self.rating}/5")
movie=movie("Inception",3.6)
movie.display_movie_details()
# Out:
# movie:Inception
# rating:3.6/5

# %%
#Delivery Address Manager
class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_delivery_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")
delivery =Delivery("Likitha","chennai")
delivery.display_delivery_details()
