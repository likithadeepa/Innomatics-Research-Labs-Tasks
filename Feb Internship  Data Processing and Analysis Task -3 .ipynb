# %%
# employee performance bonus eligibility
employees={
    "ravi":92,
    "Anita":88,
    "kiran":92,
    "suresh":85
}
highest_score =max(employees.values())
top_performers= []
for name, score in employees.items():
    if score==highest_score:
        top_performers.append(name)
print("top performers ligible for bonus:", 
      ", ".join(top_performers), 
      f"(Score: {highest_score})")
# Out:
# top performers ligible for bonus: ravi, kiran (Score: 92)

# %%
# search query keyword analysis
query="buy mobile phone buy phone online"
query=query.lower()
import string
for char in string.punctuation:
    query=query.replace(char, "")
words =query.split()
frequency={}
for word in words:
    frequency[word]=frequency.get(word, 0) + 1
result={}
for word,count in frequency.items():
    if count>1:
        result[word]=count
print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %%
# sensor data validation
sensor_readings=[3,4,7,8,10,12,5]
valid_readings=[]
for hour, value in enumerate(sensor_readings):
    if value % 2==0:  
        valid_readings.append((hour, value))
print("alid sensor readings (hour, value):")
print(valid_readings)
# Out:
# alid sensor readings (hour, value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
# Email Domain usage Analysis
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]
domain_count ={}
for email in emails:
    domain =email.split("@")[1]
    domain_count[domain]=domain_count.get(domain, 0) + 1
total_users = len(emails)
for domain, count in domain_count.items():
    percentage=(count / total_users) * 100
    print(f"{domain}:{percentage:.0f}%")
# Out:
# gmail.com:60%
# yahoo.com:40%

# %%
#  Sales Spike Detection
sales =[1200,1500,900,2200,1400,3000]
average_sales=sum(sales) /len(sales)
threshold =average_sales * 1.30
for day,value in enumerate(sales, start=1):
    if value>threshold:
        print(f"Day {day}:{value}")
# Out:
# Day 6:3000

# %%
# Duplicate User ID Detection
user_ids =["user1","user2","user1","user3","user1","user3"]
id_count={}
for user in user_ids:
    id_count[user]=id_count.get(user, 0) + 1
for user, count in id_count.items():
    if count>1:
        print(f"{user} →{count} times")
# Out:
# user1 →3 times
# user3 →2 times
